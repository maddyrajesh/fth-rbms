# %%
from itertools import combinations
from operator import itemgetter
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
customer_df = pd.read_csv('customerdata.csv',low_memory=False)
customer_df.head()
# Out:
#           version https://git-lfs.github.com/spec/v1
# 0  oid sha256:917c1a1824a1713c97dd62688a7b255aa99...
# 1                                     size 135128667

# %%
item_purchase=pd.pivot_table(customer_df,index='CUSTOMER_ID',columns=['PRODUCT_NAME'],values='QUANTITY',aggfunc='sum')

item_purchase
# Out:
# PRODUCT_NAME   Happy Milk Organic Mozzarella Cheese-200G  \
# CUSTOMER_ID
# 24                                                   NaN
# 33                                                   NaN
# 144                                                  NaN
# 159                                                  NaN
# 161                                                  NaN
# ...                                                  ...
# 539498                                               NaN
# 539500                                               NaN
# 539503                                               NaN
# 539509                                               NaN
# 539516                                               NaN
#
# PRODUCT_NAME   Om Bhakti Wick For Diya Cotton Flower Batti-100PER PACK Pouch  \
# CUSTOMER_ID
# 24                                                          NaN
# 33                                                          NaN
# ...

# %%
item_purchase.to_csv('item_purchase.csv')
