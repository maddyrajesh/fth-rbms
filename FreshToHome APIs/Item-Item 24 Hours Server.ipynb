# %%
from flask import Flask
from flask import jsonify
import pandas as pd
category = pd.read_csv('category24.csv',low_memory=False)
frequent_freq = pd.read_csv('frequent_freq24.csv',low_memory=False)


app = Flask(__name__)
@app.route('/<string:Query>/')
def Frequently_Purchase(Query):
    output = frequent_freq.sort_values(by=[Query],ascending=False)[['Unnamed: 0',Query]]
    output.rename(columns = {'Unnamed: 0':'PRODUCT_NAME', Query: 'Purchase History'}, inplace = True)
    output.reset_index(drop=True)
    output = output.loc[output['Purchase History'] > 0]
    query_db = pd.merge(output, category, how="inner", on=["PRODUCT_NAME"])
    Query_Category = query_db.loc[query_db['PRODUCT_NAME'] == Query]['CATEGORY'][0]
    query_db = query_db[1:]
    Same_Category = query_db.loc[query_db['CATEGORY'] == Query_Category]
    Not_Same_Category = query_db.loc[query_db['CATEGORY'] != Query_Category]
    Same_Category_List = Same_Category['PRODUCT_NAME'][:10].tolist()
    Not_Same_Category_List = Not_Same_Category['PRODUCT_NAME'][:10].tolist()
    return jsonify({"Same_Category": Same_Category_List, "Not_Same_Category": Not_Same_Category_List})

app.run(threaded=True)
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [13/May/2021 17:08:35] "GET /'Chitale%20Full%20Cream%20Milk-1L' HTTP/1.1" 308 -
# [2021-05-13 17:08:35,596] ERROR in app: Exception on /'Chitale Full Cream Milk-1L'/ [GET]
# Traceback (most recent call last):
#   File "c:\users\achyu\appdata\local\programs\python\python38\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "c:\users\achyu\appdata\local\programs\python\python38\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "c:\users\achyu\appdata\local\programs\python\python38\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "c:\users\achyu\appdata\local\programs\python\python38\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "c:\users\achyu\appdata\local\programs\python\python38\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "c:\users\achyu\appdata\local\programs\python\python38\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-1-6124d0038b28>", line 11, in Frequently_Purchase
#     output = frequent_freq.sort_values(by=[Query],ascending=False)[['Unnamed: 0',Query]]
#   File "c:\users\achyu\appdata\local\programs\python\python38\lib\site-packages\pandas\core\frame.py", line 5452, in sort_values
#     k = self._get_label_or_level_values(by, axis=axis)
#   File "c:\users\achyu\appdata\local\programs\python\python38\lib\site-packages\pandas\core\generic.py", line 1681, in _get_label_or_level_values
#     raise KeyError(key)
# KeyError: "'Chitale Full Cream Milk-1L'"
# 127.0.0.1 - - [13/May/2021 17:08:35] "GET /%27Chitale%20Full%20Cream%20Milk-1L%27/ HTTP/1.1" 500 -
# 127.0.0.1 - - [13/May/2021 17:09:05] "GET /Chitale%20Full%20Cream%20Milk-1L HTTP/1.1" 308 -
# 127.0.0.1 - - [13/May/2021 17:09:06] "GET /Chitale%20Full%20Cream%20Milk-1L/ HTTP/1.1" 200 -
# 127.0.0.1 - - [13/May/2021 17:14:27] "GET /sampleapi/printcust?mock_user_id=144 HTTP/1.1" 404 -
# 127.0.0.1 - - [13/May/2021 17:14:34] "GET /sampleapi/printcust?mock_user_id=33 HTTP/1.1" 404 -
# 127.0.0.1 - - [13/May/2021 17:15:09] "GET /sampleapi/printcust?mock_user_id=33 HTTP/1.1" 404 -
